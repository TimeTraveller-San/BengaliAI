# %%
import pandas as pd
import pretrainedmodels

# %%
# for x in pretrainedmodels.__dict__['pretrained_settings']:
#     print(x)

# %%
# pretrainedmodels.__dict__['pretrained_settings']['se_resnext50_32x4d']

# %%
# !ls ../logs/
# Out:
# not-pretrained-exp1.csv     se_resnext101_32x4d_2.csv
# pretrained-exp1.csv	    se_resnext101_32x4d_3.csv
# se_resnext101_32x4d_0.csv   se_resnext101_32x4d_4.csv
# se_resnext101_32x4d_10.csv  se_resnext101_32x4d_5.csv
# se_resnext101_32x4d_11.csv  se_resnext101_32x4d_6.csv
# se_resnext101_32x4d_12.csv  se_resnext101_32x4d_7.csv
# se_resnext101_32x4d_13.csv  se_resnext101_32x4d_8.csv
# se_resnext101_32x4d_1.csv   se_resnext101_32x4d_9.csv

# %%
df1 = pd.read_csv('../logs/se_resnext101_32x4d_13.csv').drop(['Unnamed: 0'], axis=1)
df2 = pd.read_csv('../logs/pretrained-exp1.csv').drop(['Unnamed: 0'], axis=1)

# %%
df1
# Out:
#     train_loss  train_recall  train_recall_grapheme  train_recall_vowel  \
# 0     2.857790      0.153579               0.019789            0.329708
# 1     1.582811      0.447909               0.237073            0.621420
# 2     0.869889      0.641872               0.493240            0.751756
# 3     0.722098      0.700481               0.572237            0.810875
# 4     0.653342      0.724598               0.607398            0.828847
# 5     0.622203      0.739717               0.628973            0.840515
# 6     0.622315      0.741168               0.628433            0.845390
# 7     0.599670      0.749305               0.638393            0.851953
# 8     0.549146      0.771519               0.666024            0.869491
# 9     0.522696      0.781203               0.680697            0.876892
# 10    0.505543      0.786997               0.689625            0.880063
# 11    0.493724      0.790937               0.693747            0.885596
# ...

# %%
df2
# Out:
#     train_loss  train_recall  train_acc_grapheme  train_acc_vowel  \
# 0     0.625307      0.743177            0.737785         0.900265
# 1     0.305778      0.855398            0.866846         0.951049
# 2     0.246591      0.879242            0.891446         0.960294
# 3     0.215192      0.893393            0.904441         0.965787
# 4     0.194135      0.903426            0.914053         0.968965
# 5     0.179257      0.909576            0.920047         0.971166
# 6     0.165977      0.915260            0.925356         0.973182
# 7     0.156747      0.919602            0.929874         0.974443
# 8     0.148719      0.923348            0.932575         0.975806
# 9     0.142007      0.926574            0.935849         0.976433
# 10    0.134877      0.929197            0.938705         0.977389
# 11    0.130699      0.931716            0.940983         0.978273
# 12    0.126918      0.933043            0.942165         0.978534
#
# ...
